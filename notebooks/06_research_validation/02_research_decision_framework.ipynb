# %% [markdown]
# # Research Decision Framework
#
# ## Objective
#
# This notebook converts the validated covariance research into an
# explicit portfolio decision framework.
#
# The objective is not to select a methodology solely according to
# historical return.
#
# Instead, the decision considers:
#
# - risk-adjusted performance;
# - downside risk;
# - portfolio turnover;
# - implementation characteristics;
# - robustness across specifications; and
# - research limitations.
#
# The final recommendation must therefore be conditional on the
# investment objective and the evidence generated by CARL.

# %%
# We reconstruct the validated evidence from the artifacts created

from pathlib import Path
import pandas as pd

evidence_dir = Path(
    "outputs/research_validation"
)

evidence_matrix = pd.read_csv(
    evidence_dir / "evidence_matrix.csv"
)

research_validation = pd.read_csv(
    evidence_dir / "research_validation.csv"
)

training_window_evidence = pd.read_csv(
    evidence_dir / "training_window_evidence.csv"
)

ranking_table = pd.read_csv(
    evidence_dir / "ranking_stability.csv"
)

shrinkage_tradeoff = pd.read_csv(
    evidence_dir / "shrinkage_tradeoff.csv"
)

# %%
research_validation
# Out:
#                      Dimension  \
# 0            Research question
# 1         Out-of-sample design
# 2           Covariance methods
# 3  Training-window sensitivity
# 4        Shrinkage sensitivity
# 5           Performance leader
# 6              Drawdown leader
# 7       Turnover consideration
# 8               Generalization
#
#                                               Result
# 0  Covariance methodology affects GMV portfolio o...
# 1                    Strict walk-forward evaluation.
# 2                    Sample, shrinkage, Ledoit-Wolf.
# 3  Ranking remained stable across 126, 252, and 5...
# 4  Performance declined progressively as shrinkag...
# 5                                 Sample covariance.
# 6     Ledoit-Wolf among the tested baseline methods.
# 7  Shrinkage reduced turnover relative to sample ...
# 8  Conclusions remain conditional on the tested r...

# %% [markdown]
# ## Decision Criteria
#
# The covariance methodology will be evaluated using five criteria.
#
# ### 1. Risk-adjusted performance
#
# Primary measures:
#
# - Sharpe ratio
# - Sortino ratio
# - Calmar ratio
#
# ### 2. Absolute performance
#
# Supporting measures:
#
# - total return
# - annualized return
#
# ### 3. Downside risk
#
# Primary measure:
#
# - maximum drawdown
#
# ### 4. Implementation characteristics
#
# Primary measure:
#
# - average turnover
#
# ### 5. Robustness
#
# The preferred methodology should not depend entirely on one
# training-window specification.

# %% [markdown]
# ## Decision Philosophy
#
# No single metric determines the final decision.
#
# A methodology with the highest return but substantially worse
# implementation characteristics should not automatically be treated
# as superior.
#
# Similarly, a methodology with the lowest drawdown should not
# automatically be preferred if it materially sacrifices
# risk-adjusted performance.
#
# The decision therefore evaluates the covariance estimators as
# different points on a performance-risk-implementation trade-off
# rather than attempting to identify a universally optimal method.

# %%
import pandas as pd

from crypto_alpha_lab.data import load_prices
from crypto_alpha_lab.evaluation.covariance_comparison import (
    compare_covariance_methods,
)
from crypto_alpha_lab.research.covariance_experiment import (
    run_covariance_experiment,
)

# %%
assets = {
    "BTC": "BTC-USD",
    "ETH": "ETH-USD",
    "SOL": "SOL-USD",
}

close_prices = pd.concat(
    {
        name: load_prices(
            ticker,
            "2021-01-01",
            "2025-12-31",
            refresh=False,
        )["Close"]
        for name, ticker in assets.items()
    },
    axis=1,
).dropna()

close_prices
# Out:
#                      BTC          ETH         SOL
# Date
# 2021-01-01  29374.152344   730.367554    1.842084
# 2021-01-02  32127.267578   774.534973    1.799275
# 2021-01-03  32782.023438   975.507690    2.161752
# 2021-01-04  31971.914062  1040.233032    2.485097
# 2021-01-05  33992.429688  1100.006104    2.157217
# ...                  ...          ...         ...
# 2025-12-26  87301.429688  2925.745605  122.195953
# 2025-12-27  87802.156250  2947.998291  124.647713
# 2025-12-28  87835.835938  2948.568115  125.199356
# 2025-12-29  87138.140625  2934.538330  123.125229
# 2025-12-30  88430.132812  2971.416748  124.931320
#
# [1825 rows x 3 columns]

# %%
experiments = [
    run_covariance_experiment(
        prices=close_prices,
        method="sample",
        train_size=252,
        test_size=21,
    ),
    run_covariance_experiment(
        prices=close_prices,
        method="shrinkage",
        train_size=252,
        test_size=21,
        shrinkage=0.25,
    ),
    run_covariance_experiment(
        prices=close_prices,
        method="ledoit_wolf",
        train_size=252,
        test_size=21,
    ),
]
experiments
# Out:
# [CovarianceExperimentResult(method='sample', returns=Date
#  2021-09-10   -0.031215
#  2021-09-11    0.005322
#  2021-09-12    0.014107
#  2021-09-13   -0.023459
#  2021-09-14    0.039047
#                  ...
#  2025-12-07    0.014021
#  2025-12-08    0.000522
#  2025-12-09    0.018193
#  2025-12-10   -0.007876
#  2025-12-11    0.008675
#  Length: 1554, dtype: float64, cumulative_returns=Date
#  2021-09-10   -0.031215
#  2021-09-11   -0.026060
#  2021-09-12   -0.012320
#  2021-09-13   -0.035490
#  2021-09-14    0.002171
#                  ...
#  2025-12-07    0.833999
#  2025-12-08    0.834956
#  2025-12-09    0.868339
#  2025-12-10    0.853624
#  2025-12-11    0.869704
#  Length: 1554, dtype: float64, folds=(BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2021-09-10 -0.032495 -0.062974 -0.044265
#  2021-09-11  0.007075  0.018301 -0.005545
#  2021-09-12  0.019066  0.042766 -0.024209
#  2021-09-13 -0.023884 -0.036545 -0.030183
#  2021-09-14  0.047359  0.043725 -0.066017
#  2021-09-15  0.023015  0.054273  0.006468
#  2021-09-16 -0.008157 -0.012167 -0.041751
#  2021-09-17 -0.010795 -0.048374 -0.032012
#  2021-09-18  0.021386  0.009851  0.146288
#  2021-09-19 -0.021089 -0.029886 -0.098517
#  2021-09-20 -0.093449 -0.111266 -0.133639
#  2021-09-21 -0.050185 -0.065753 -0.061937
#  2021-09-22  0.070793  0.113382  0.193415
#  2021-09-23  0.030306  0.025230  0.012367
#  2021-09-24 -0.045781 -0.070941 -0.069166
#  2021-09-25 -0.002875 -0.002082 -0.023076
#  2021-09-26  0.011516  0.046726 -0.003521
#  2021-09-27 -0.022514 -0.041840  0.007583
#  2021-09-28 -0.028440 -0.043230 -0.037967
#  2021-09-29  0.012912  0.016331  0.028997
#  2021-09-30  0.053568  0.052060  0.042243, portfolio_returns=Date
#  2021-09-10   -0.031215
#  2021-09-11    0.005322
#  2021-09-12    0.014107
#  2021-09-13   -0.023459
#  2021-09-14    0.039047
#  2021-09-15    0.019539
#  2021-09-16   -0.010411
#  2021-09-17   -0.009724
#  2021-09-18    0.031649
#  2021-09-19   -0.026316
#  2021-09-20   -0.095219
#  2021-09-21   -0.049965
#  2021-09-22    0.077031
#  2021-09-23    0.029312
#  2021-09-24   -0.045758
#  2021-09-25   -0.004458
#  2021-09-26    0.007873
#  2021-09-27   -0.018863
#  2021-09-28   -0.028107
#  2021-09-29    0.013884
#  2021-09-30    0.052819
#  dtype: float64, cumulative_returns=Date
#  2021-09-10   -0.031215
#  2021-09-11   -0.026060
#  2021-09-12   -0.012320
#  2021-09-13   -0.035490
#  2021-09-14    0.002171
#  2021-09-15    0.021752
#  2021-09-16    0.011114
#  2021-09-17    0.001282
#  2021-09-18    0.032972
#  2021-09-19    0.005788
#  2021-09-20   -0.089981
#  2021-09-21   -0.135451
#  2021-09-22   -0.068854
#  2021-09-23   -0.041560
#  2021-09-24   -0.085416
#  2021-09-25   -0.089494
#  2021-09-26   -0.082326
#  2021-09-27   -0.099636
#  2021-09-28   -0.124943
#  2021-09-29   -0.112793
#  2021-09-30   -0.065931
#  dtype: float64, weights=BTC    0.995604
#  ETH   -0.071203
#  SOL    0.075599
#  Name: weight, dtype: float64, turnover=1.1424056559181621, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 0, 'covariance_method': 'sample', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2021-09-09 00:00:00'), 'test_start': Timestamp('2021-09-10 00:00:00'), 'test_end': Timestamp('2021-09-30 00:00:00')}), BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2021-10-01  0.098789  0.101889  0.146122
#  2021-10-02 -0.008426  0.025451  0.045835
#  2021-10-03  0.010238  0.007862  0.020676
#  2021-10-04  0.018941 -0.011195 -0.033937
#  2021-10-05  0.048906  0.040954 -0.015690
#  2021-10-06  0.074670  0.017633 -0.060982
#  2021-10-07 -0.028097  0.002070  0.001125
#  2021-10-08  0.003008 -0.006749  0.030257
#  2021-10-09  0.018536  0.003355 -0.013359
#  2021-10-10 -0.003577 -0.041912 -0.055967
#  2021-10-11  0.049537  0.034882 -0.021551
#  2021-10-12 -0.025115 -0.014887  0.054391
#  2021-10-13  0.024269  0.032534 -0.029862
#  2021-10-14 -0.001386  0.049862  0.010668
#  2021-10-15  0.074534  0.020238  0.085735
#  2021-10-16 -0.011393 -0.008350 -0.031104
#  2021-10-17  0.010862  0.004366  0.013996
#  2021-10-18  0.007676 -0.025563 -0.015728
#  2021-10-19  0.036048  0.034382 -0.007723
#  2021-10-20  0.026934  0.071781  0.127741
#  2021-10-21 -0.057319 -0.024463  0.081681, portfolio_returns=Date
#  2021-10-01    0.101790
#  2021-10-02   -0.007796
#  2021-10-03    0.011183
#  2021-10-04    0.018060
#  2021-10-05    0.045155
#  2021-10-06    0.070532
#  2021-10-07   -0.028862
#  2021-10-08    0.005805
#  2021-10-09    0.017728
#  2021-10-10   -0.003665
#  2021-10-11    0.045956
#  2021-10-12   -0.020539
#  2021-10-13    0.019742
#  2021-10-14   -0.005298
#  2021-10-15    0.080344
#  2021-10-16   -0.013045
#  2021-10-17    0.011682
#  2021-10-18    0.009130
#  2021-10-19    0.033162
#  2021-10-20    0.029781
#  2021-10-21   -0.050708
#  dtype: float64, cumulative_returns=Date
#  2021-10-01    0.101790
#  2021-10-02    0.093200
#  2021-10-03    0.105425
#  2021-10-04    0.125390
#  2021-10-05    0.176207
#  2021-10-06    0.259167
#  2021-10-07    0.222825
#  2021-10-08    0.229924
#  2021-10-09    0.251728
#  2021-10-10    0.247141
#  2021-10-11    0.304455
#  2021-10-12    0.277662
#  2021-10-13    0.302886
#  2021-10-14    0.295983
#  2021-10-15    0.400108
#  2021-10-16    0.381843
#  2021-10-17    0.397986
#  2021-10-18    0.410750
#  2021-10-19    0.457533
#  2021-10-20    0.500940
#  2021-10-21    0.424831
#  dtype: float64, weights=BTC    1.023198
#  ETH   -0.092669
#  SOL    0.069470
#  Name: weight, dtype: float64, turnover=1.1853372211420337, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 1, 'covariance_method': 'sample', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2021-09-30 00:00:00'), 'test_start': Timestamp('2021-10-01 00:00:00'), 'test_end': Timestamp('2021-10-21 00:00:00')}), BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2021-10-22 -0.024400 -0.020753  0.032120
#  2021-10-23  0.011556  0.050749  0.006477
#  2021-10-24 -0.007538 -0.020078  0.023561
#  2021-10-25  0.034613  0.031795  0.038260
#  2021-10-26 -0.042450 -0.020573 -0.049009
#  2021-10-27 -0.031168 -0.048618 -0.080241
#  2021-10-28  0.036588  0.090849  0.060342
#  2021-10-29  0.026489  0.029722  0.027295
#  2021-10-30 -0.005450 -0.020181 -0.023812
#  2021-10-31 -0.009208 -0.008687  0.035846
#  2021-11-01 -0.005130  0.008524  0.005553
#  2021-11-02  0.036424  0.060161  0.082019
#  2021-11-03 -0.004055  0.004885  0.102884
#  2021-11-04 -0.024104 -0.015165  0.018481
#  2021-11-05 -0.005314 -0.011258 -0.044115
#  2021-11-06  0.006573  0.007877  0.094979
#  2021-11-07  0.029247  0.021889 -0.035186
#  2021-11-08  0.066952  0.041452 -0.005429
#  2021-11-09 -0.008806 -0.016005 -0.037245
#  2021-11-10 -0.029514 -0.020886 -0.022715
#  2021-11-11 -0.000697  0.020321  0.001973, portfolio_returns=Date
#  2021-10-22   -0.020243
#  2021-10-23    0.008438
#  2021-10-24   -0.004241
#  2021-10-25    0.035093
#  2021-10-26   -0.044481
#  2021-10-27   -0.033785
#  2021-10-28    0.034673
#  2021-10-29    0.026327
#  2021-10-30   -0.005859
#  2021-10-31   -0.005729
#  2021-11-01   -0.005245
#  2021-11-02    0.038332
#  2021-11-03    0.003668
#  2021-11-04   -0.021402
#  2021-11-05   -0.007928
#  2021-11-06    0.013380
#  2021-11-07    0.024731
#  2021-11-08    0.063075
#  2021-11-09   -0.010525
#  2021-11-10   -0.029583
#  2021-11-11   -0.001948
#  dtype: float64, cumulative_returns=Date
#  2021-10-22   -0.020243
#  2021-10-23   -0.011976
#  2021-10-24   -0.016166
#  2021-10-25    0.018360
#  2021-10-26   -0.026938
#  2021-10-27   -0.059812
#  2021-10-28   -0.027213
#  2021-10-29   -0.001602
#  2021-10-30   -0.007452
#  2021-10-31   -0.013139
#  2021-11-01   -0.018314
#  2021-11-02    0.019316
#  2021-11-03    0.023055
#  2021-11-04    0.001160
#  2021-11-05   -0.006778
#  2021-11-06    0.006512
#  2021-11-07    0.031404
#  2021-11-08    0.096460
#  2021-11-09    0.084920
#  2021-11-10    0.052825
#  2021-11-11    0.050774
#  dtype: float64, weights=BTC    0.991427
#  ETH   -0.069448
#  SOL    0.078021
#  Name: weight, dtype: float64, turnover=1.13889669259315, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 2, 'covariance_method': 'sample', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2021-10-21 00:00:00'), 'test_start': Timestamp('2021-10-22 00:00:00'), 'test_end': Timestamp('2021-11-11 00:00:00')}), BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2021-11-12 -0.012225 -0.013375 -0.024499
#  2021-11-13  0.004888 -0.003354  0.058306
#  2021-11-14  0.015470 -0.005396 -0.014058
#  2021-11-15 -0.029159 -0.014883 -0.003657
#  2021-11-16 -0.053441 -0.074852 -0.077097
#  2021-11-17  0.003437  0.016893 -0.002389
#  2021-11-18 -0.056750 -0.066924 -0.106201
#  2021-11-19  0.020678  0.074402  0.101247
#  2021-11-20  0.027144  0.025969  0.012706
#  2021-11-21 -0.016194 -0.031791  0.060855
#  2021-11-22 -0.041566 -0.042456 -0.067214
#  2021-11-23  0.022736  0.061712  0.028273
#  2021-11-24 -0.022384 -0.023218 -0.031173
#  2021-11-25  0.017666  0.008199 -0.040334
#  2021-11-26 -0.064687 -0.057041 -0.071472
#  2021-11-27  0.023247  0.016374  0.008304
#  2021-11-28  0.044393  0.048217  0.039225
#  2021-11-29  0.009749  0.035080  0.018152
#  2021-11-30 -0.013859  0.041928  0.021298
#  2021-12-01  0.003937 -0.009606  0.101251
#  2021-12-02 -0.013140 -0.016501  0.018250, portfolio_returns=Date
#  2021-11-12   -0.013116
#  2021-11-13    0.009704
#  2021-11-14    0.014608
#  2021-11-15   -0.028150
#  2021-11-16   -0.053799
#  2021-11-17    0.002022
#  2021-11-18   -0.059947
#  2021-11-19    0.023256
#  2021-11-20    0.026084
#  2021-11-21   -0.008984
#  2021-11-22   -0.043535
#  2021-11-23    0.020413
#  2021-11-24   -0.023022
#  2021-11-25    0.013741
#  2021-11-26   -0.065766
#  2021-11-27    0.022550
#  2021-11-28    0.043712
#  2021-11-29    0.008620
#  2021-11-30   -0.015025
#  2021-12-01    0.012606
#  2021-12-02   -0.010415
#  dtype: float64, cumulative_returns=Date
#  2021-11-12   -0.013116
#  2021-11-13   -0.003539
#  2021-11-14    0.011017
#  2021-11-15   -0.017443
#  2021-11-16   -0.070303
#  2021-11-17   -0.068424
#  2021-11-18   -0.124269
#  2021-11-19   -0.103903
#  2021-11-20   -0.080530
#  2021-11-21   -0.088791
#  2021-11-22   -0.128460
#  2021-11-23   -0.110669
#  2021-11-24   -0.131143
#  2021-11-25   -0.119204
#  2021-11-26   -0.177130
#  2021-11-27   -0.158575
#  2021-11-28   -0.121794
#  2021-11-29   -0.114224
#  2021-11-30   -0.127533
#  2021-12-01   -0.116535
#  2021-12-02   -0.125736
#  dtype: float64, weights=BTC    0.991610
#  ETH   -0.070842
#  SOL    0.079231
#  Name: weight, dtype: float64, turnover=1.1416832341564935, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 3, 'covariance_method': 'sample', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2021-11-11 00:00:00'), 'test_start': Timestamp('2021-11-12 00:00:00'), 'test_end': Timestamp('2021-12-02 00:00:00')}), BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2021-12-03 -0.050986 -0.064415 -0.097305
#  2021-12-04 -0.082046 -0.023958 -0.047814
#  2021-12-05  0.003418  0.019112 -0.024644
#  2021-12-06  0.024586  0.038209 -0.010038
#  2021-12-07  0.002322 -0.010020 -0.018550
#  2021-12-08 -0.003852  0.028805  0.021117
#  2021-12-09 -0.056087 -0.071979 -0.069076
#  2021-12-10 -0.008995 -0.051294 -0.072985
#  2021-12-11  0.044857  0.045019  0.023784
#  2021-12-12  0.014907  0.012242  0.008620
#  2021-12-13 -0.067085 -0.084709 -0.105048
#  2021-12-14 -0.002671 -0.010249 -0.012058
#  2021-12-15  0.049002  0.072875  0.163031
#  2021-12-16 -0.025182 -0.013916 -0.007772
#  2021-12-17 -0.030699 -0.020942 -0.008202
#  2021-12-18  0.013996  0.020975  0.041776
#  2021-12-19 -0.003026 -0.009661 -0.014970
#  2021-12-20  0.003710  0.002868 -0.035682
#  2021-12-21  0.043864  0.021967  0.036971
#  2021-12-22 -0.006296 -0.009492 -0.008304
#  2021-12-23  0.044337  0.031621  0.064050, portfolio_returns=Date
#  2021-12-03   -0.053515
#  2021-12-04   -0.083717
#  2021-12-05    0.000134
#  2021-12-06    0.020957
#  2021-12-07    0.001645
#  2021-12-08   -0.004357
#  2021-12-09   -0.055905
#  2021-12-10   -0.010743
#  2021-12-11    0.043246
#  2021-12-12    0.014625
#  2021-12-13   -0.068671
#  2021-12-14   -0.002827
#  2021-12-15    0.055902
#  2021-12-16   -0.024688
#  2021-12-17   -0.029709
#  2021-12-18    0.015591
#  2021-12-19   -0.003445
#  2021-12-20    0.000781
#  2021-12-21    0.044950
#  2021-12-22   -0.006213
#  2021-12-23    0.046768
#  dtype: float64, cumulative_returns=Date
#  2021-12-03   -0.053515
#  2021-12-04   -0.132752
#  2021-12-05   -0.132636
#  2021-12-06   -0.114459
#  2021-12-07   -0.113002
#  2021-12-08   -0.116866
#  2021-12-09   -0.166238
#  2021-12-10   -0.175195
#  2021-12-11   -0.139526
#  2021-12-12   -0.126941
#  2021-12-13   -0.186895
#  2021-12-14   -0.189194
#  2021-12-15   -0.143868
#  2021-12-16   -0.165005
#  2021-12-17   -0.189811
#  2021-12-18   -0.177179
#  2021-12-19   -0.180014
#  2021-12-20   -0.179373
#  2021-12-21   -0.142486
#  2021-12-22   -0.147814
#  2021-12-23   -0.107959
#  dtype: float64, weights=BTC    0.997594
#  ETH   -0.073497
#  SOL    0.075902
#  Name: weight, dtype: float64, turnover=1.1469934763031424, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 4, 'covariance_method': 'sample', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2021-12-02 00:00:00'), 'test_start': Timestamp('2021-12-03 00:00:00'), 'test_end': Timestamp('2021-12-23 00:00:00')}), BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2021-12-24  0.000741 -0.014614  0.001246
#  2021-12-25 -0.007720  0.011190  0.014967
#  2021-12-26  0.007528 -0.006340  0.025268
#  2021-12-27 -0.003328 -0.007322 -0.012986
#  2021-12-28 -0.060259 -0.058613 -0.092125
#  2021-12-29 -0.024042 -0.045348 -0.038146
#  2021-12-30  0.015791  0.023514  0.012268
#  2021-12-31 -0.018476 -0.008406 -0.014195
#  2022-01-01  0.029809  0.023642  0.048261
#  2022-01-02 -0.007163  0.015881 -0.011960
#  2022-01-03 -0.018737 -0.017805 -0.034499
#  2022-01-04 -0.012066  0.008687 -0.013851
#  2022-01-05 -0.050734 -0.064224 -0.076451
#  2022-01-06 -0.009366 -0.037173 -0.030099
#  2022-01-07 -0.037141 -0.065878 -0.093255
#  2022-01-08  0.004236 -0.031704  0.044798
#  2022-01-09  0.004257  0.021274 -0.011749
#  2022-01-10 -0.002155 -0.023641 -0.034678
#  2022-01-11  0.021869  0.050279  0.031105
#  2022-01-12  0.028389  0.041427  0.082172
#  2022-01-13 -0.030889 -0.036762 -0.037528, portfolio_returns=Date
#  2021-12-24    0.001792
#  2021-12-25   -0.007385
#  2021-12-26    0.009685
#  2021-12-27   -0.003739
#  2021-12-28   -0.062594
#  2021-12-29   -0.023619
#  2021-12-30    0.015034
#  2021-12-31   -0.018843
#  2022-01-01    0.031506
#  2022-01-02   -0.009022
#  2022-01-03   -0.019900
#  2022-01-04   -0.013562
#  2022-01-05   -0.051639
#  2022-01-06   -0.008976
#  2022-01-07   -0.039161
#  2022-01-08    0.009446
#  2022-01-09    0.002014
#  2022-01-10   -0.003007
#  2022-01-11    0.020636
#  2022-01-12    0.031285
#  2022-01-13   -0.030964
#  dtype: float64, cumulative_returns=Date
#  2021-12-24    0.001792
#  2021-12-25   -0.005606
#  2021-12-26    0.004024
#  2021-12-27    0.000270
#  2021-12-28   -0.062341
#  2021-12-29   -0.084488
#  2021-12-30   -0.070723
#  2021-12-31   -0.088234
#  2022-01-01   -0.059507
#  2022-01-02   -0.067993
#  2022-01-03   -0.086539
#  2022-01-04   -0.098928
#  2022-01-05   -0.145458
#  2022-01-06   -0.153129
#  2022-01-07   -0.186293
#  2022-01-08   -0.178607
#  2022-01-09   -0.176953
#  2022-01-10   -0.179428
#  2022-01-11   -0.162494
#  2022-01-12   -0.136293
#  2022-01-13   -0.163037
#  dtype: float64, weights=BTC    0.996256
#  ETH   -0.066116
#  SOL    0.069860
#  Name: weight, dtype: float64, turnover=1.132232002602683, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 5, 'covariance_method': 'sample', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2021-12-23 00:00:00'), 'test_start': Timestamp('2021-12-24 00:00:00'), 'test_end': Timestamp('2022-01-13 00:00:00')}), BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2022-01-14  0.011930  0.018999  0.001020
#  2022-01-15  0.001803  0.006202  0.011235
#  2022-01-16 -0.001471  0.006122  0.000374
#  2022-01-17 -0.020024 -0.041367 -0.053637
#  2022-01-18  0.002960 -0.015030  0.011872
#  2022-01-19 -0.014898 -0.021555 -0.040927
#  2022-01-20 -0.025486 -0.030591 -0.063237
#  2022-01-21 -0.103812 -0.147674 -0.119800
#  2022-01-22 -0.039143 -0.059716 -0.158867
#  2022-01-23  0.035585  0.053991  0.057336
#  2022-01-24  0.010407 -0.037351 -0.079616
#  2022-01-25  0.008176  0.006385  0.033499
#  2022-01-26 -0.002757  0.004925 -0.026207
#  2022-01-27  0.007764 -0.018245 -0.028248
#  2022-01-28  0.017397  0.051214  0.018748
#  2022-01-29  0.009365  0.019627  0.053778
#  2022-01-30 -0.005784  0.002457 -0.030406
#  2022-01-31  0.014915  0.032577  0.069039
#  2022-02-01  0.006760  0.038626  0.102670
#  2022-02-02 -0.046209 -0.039133 -0.074027
#  2022-02-03  0.005456 -0.001376 -0.003717, portfolio_returns=Date
#  2022-01-14    0.010734
#  2022-01-15    0.002107
#  2022-01-16   -0.001879
#  2022-01-17   -0.020716
#  2022-01-18    0.004785
#  2022-01-19   -0.016119
#  2022-01-20   -0.027573
#  2022-01-21   -0.101802
#  2022-01-22   -0.045457
#  2022-01-23    0.035714
#  2022-01-24    0.007901
#  2022-01-25    0.009937
#  2022-01-26   -0.004806
#  2022-01-27    0.007240
#  2022-01-28    0.015138
#  2022-01-29    0.011524
#  2022-01-30   -0.007948
#  2022-01-31    0.017188
#  2022-02-01    0.010750
#  2022-02-02   -0.048499
#  2022-02-03    0.005337
#  dtype: float64, cumulative_returns=Date
#  2022-01-14    0.010734
#  2022-01-15    0.012864
#  2022-01-16    0.010961
#  2022-01-17   -0.009982
#  2022-01-18   -0.005245
#  2022-01-19   -0.021279
#  2022-01-20   -0.048265
#  2022-01-21   -0.145153
#  2022-01-22   -0.184012
#  2022-01-23   -0.154869
#  2022-01-24   -0.148192
#  2022-01-25   -0.139728
#  2022-01-26   -0.143862
#  2022-01-27   -0.137664
#  2022-01-28   -0.124610
#  2022-01-29   -0.114522
#  2022-01-30   -0.121559
#  2022-01-31   -0.106460
#  2022-02-01   -0.096855
#  2022-02-02   -0.140656
#  2022-02-03   -0.136070
#  dtype: float64, weights=BTC    1.004741
#  ETH   -0.069396
#  SOL    0.064655
#  Name: weight, dtype: float64, turnover=1.138792123543411, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 6, 'covariance_method': 'sample', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2022-01-13 00:00:00'), 'test_start': Timestamp('2022-01-14 00:00:00'), 'test_end': Timestamp('2022-02-03 00:00:00')}), BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2022-02-04  0.116978  0.113627  0.105611
#  2022-02-05 -0.001439  0.010411  0.015334
#  2022-02-06  0.023437  0.014207  0.012340
#  2022-02-07  0.033666  0.027799  0.017826
#  2022-02-08  0.006345 -0.006321 -0.032037
#  2022-02-09  0.004995  0.037420  0.003732
#  2022-02-10 -0.017449 -0.050001 -0.068555
#  2022-02-11 -0.026562 -0.048773 -0.092473
#  2022-02-12 -0.003855 -0.003423 -0.004811
#  2022-02-13 -0.001111 -0.011620 -0.027879
#  2022-02-14  0.009228  0.017346  0.034202
#  2022-02-15  0.046688  0.083995  0.087522
#  2022-02-16 -0.013760 -0.016368 -0.028038
#  2022-02-17 -0.077882 -0.078760 -0.083609
#  2022-02-18 -0.012508 -0.033231 -0.035809
#  2022-02-19  0.002278 -0.007907  0.015891
#  2022-02-20 -0.042141 -0.048867 -0.006506
#  2022-02-21 -0.035286 -0.020859 -0.085568
#  2022-02-22  0.032656  0.025442  0.040208
#  2022-02-23 -0.025844 -0.018543 -0.018072
#  2022-02-24  0.027778  0.002975  0.050551, portfolio_returns=Date
#  2022-02-04    0.116574
#  2022-02-05   -0.001402
#  2022-02-06    0.023526
#  2022-02-07    0.033200
#  2022-02-08    0.005089
#  2022-02-09    0.002288
#  2022-02-10   -0.017848
#  2022-02-11   -0.028681
#  2022-02-12   -0.003947
#  2022-02-13   -0.001851
#  2022-02-14    0.010055
#  2022-02-15    0.046090
#  2022-02-16   -0.014398
#  2022-02-17   -0.078152
#  2022-02-18   -0.012212
#  2022-02-19    0.003914
#  2022-02-20   -0.039474
#  2022-02-21   -0.039449
#  2022-02-22    0.033691
#  2022-02-23   -0.025974
#  2022-02-24    0.031146
#  dtype: float64, cumulative_returns=Date
#  2022-02-04    0.116574
#  2022-02-05    0.115008
#  2022-02-06    0.141240
#  2022-02-07    0.179128
#  2022-02-08    0.185129
#  2022-02-09    0.187840
#  2022-02-10    0.166639
#  2022-02-11    0.133178
#  2022-02-12    0.128706
#  2022-02-13    0.126617
#  2022-02-14    0.137945
#  2022-02-15    0.190392
#  2022-02-16    0.173254
#  2022-02-17    0.081562
#  2022-02-18    0.068353
#  2022-02-19    0.072535
#  2022-02-20    0.030198
#  2022-02-21   -0.010443
#  2022-02-22    0.022897
#  2022-02-23   -0.003672
#  2022-02-24    0.027360
#  dtype: float64, weights=BTC    1.021658
#  ETH   -0.081161
#  SOL    0.059503
#  Name: weight, dtype: float64, turnover=1.1623219693691036, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 7, 'covariance_method': 'sample', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2022-02-03 00:00:00'), 'test_start': Timestamp('2022-02-04 00:00:00'), 'test_end': Timestamp('2022-02-24 00:00:00')}), BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2022-02-25  0.022999  0.064074  0.038165
#  2022-02-26 -0.002781  0.005996 -0.026537
#  2022-02-27 -0.035682 -0.057283 -0.051281
#  2022-02-28  0.145412  0.113433  0.163721
#  2022-03-01  0.026889  0.018253 -0.008710
#  2022-03-02 -0.009706 -0.007525  0.020233
#  2022-03-03 -0.033520 -0.039202 -0.050775
#  2022-03-04 -0.078069 -0.076668 -0.076337
#  2022-03-05  0.006719  0.018216  0.015886
#  2022-03-06 -0.024888 -0.041201 -0.056952
#  2022-03-07 -0.009317 -0.022413 -0.028532
#  2022-03-08  0.017740  0.031619  0.001518
#  2022-03-09  0.083786  0.059391  0.072303
#  2022-03-10 -0.060631 -0.044595 -0.059670
#  2022-03-11 -0.016291 -0.018591 -0.026454
#  2022-03-12  0.002811  0.005935  0.010017
#  2022-03-13 -0.027101 -0.021676 -0.032098
#  2022-03-14  0.048008  0.028485  0.028343
#  2022-03-15 -0.008268  0.011369  0.021950
#  2022-03-16  0.045887  0.057976  0.059653
#  2022-03-17 -0.004680  0.015439 -0.000305, portfolio_returns=Date
#  2022-02-25    0.020506
#  2022-02-26   -0.004863
#  2022-02-27   -0.034809
#  2022-02-28    0.149080
#  2022-03-01    0.025553
#  2022-03-02   -0.008168
#  2022-03-03   -0.034044
#  2022-03-04   -0.078085
#  2022-03-05    0.006304
#  2022-03-06   -0.025392
#  2022-03-07   -0.009347
#  2022-03-08    0.015674
#  2022-03-09    0.085125
#  2022-03-10   -0.061889
#  2022-03-11   -0.016686
#  2022-03-12    0.002968
#  2022-03-13   -0.027832
#  2022-03-14    0.048478
#  2022-03-15   -0.008142
#  2022-03-16    0.045687
#  2022-03-17   -0.006076
#  dtype: float64, cumulative_returns=Date
#  2022-02-25    0.020506
#  2022-02-26    0.015544
#  2022-02-27   -0.019806
#  2022-02-28    0.126321
#  2022-03-01    0.155103
#  2022-03-02    0.145669
#  2022-03-03    0.106665
#  2022-03-04    0.020251
#  2022-03-05    0.026683
#  2022-03-06    0.000614
#  2022-03-07   -0.008739
#  2022-03-08    0.006798
#  2022-03-09    0.092501
#  2022-03-10    0.024888
#  2022-03-11    0.007787
#  2022-03-12    0.010778
#  2022-03-13   -0.017354
#  2022-03-14    0.030283
#  2022-03-15    0.021894
#  2022-03-16    0.068581
#  2022-03-17    0.062089
#  dtype: float64, weights=BTC    1.024505
#  ETH   -0.081867
#  SOL    0.057363
#  Name: weight, dtype: float64, turnover=1.1637343395865472, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 8, 'covariance_method': 'sample', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2022-02-24 00:00:00'), 'test_start': Timestamp('2022-02-25 00:00:00'), 'test_end': Timestamp('2022-03-17 00:00:00')}), BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2022-03-18  0.020751  0.046357  0.022135
#  2022-03-19  0.009318  0.000310  0.028903
#  2022-03-20 -0.022347 -0.029121 -0.041153
#  2022-03-21 -0.004117  0.013116  0.001606
#  2022-03-22  0.031180  0.025933  0.019782
#  2022-03-23  0.012610  0.019487  0.050708
#  2022-03-24  0.024899  0.025402  0.074877
#  2022-03-25  0.008821 -0.000447 -0.034880
#  2022-03-26  0.003430  0.011751  0.031483
#  2022-03-27  0.052126  0.047213  0.052278
#  2022-03-28  0.006568  0.013689 -0.005780
#  2022-03-29  0.007166  0.019587  0.049265
#  2022-03-30 -0.008492 -0.004947  0.080469
#  2022-03-31 -0.032382 -0.030579  0.016255
#  2022-04-01  0.016315  0.051166  0.095951
#  2022-04-02 -0.008917 -0.001302 -0.016604
#  2022-04-03  0.012745  0.022576  0.034618
#  2022-04-04  0.003640 -0.000452 -0.031897
#  2022-04-05 -0.022879 -0.031082 -0.041917
#  2022-04-06 -0.051568 -0.070374 -0.110189
#  2022-04-07  0.006876  0.019416  0.052383, portfolio_returns=Date
#  2022-03-18    0.019121
#  2022-03-19    0.010975
#  2022-03-20   -0.022912
#  2022-03-21   -0.004955
#  2022-03-22    0.030914
#  2022-03-23    0.014210
#  2022-03-24    0.027565
#  2022-03-25    0.007078
#  2022-03-26    0.004391
#  2022-03-27    0.052462
#  2022-03-28    0.005427
#  2022-03-29    0.008613
#  2022-03-30   -0.003923
#  2022-03-31   -0.029875
#  2022-04-01    0.018297
#  2022-04-02   -0.009839
#  2022-04-03    0.013272
#  2022-04-04    0.001993
#  2022-04-05   -0.023361
#  2022-04-06   -0.053483
#  2022-04-07    0.008500
#  dtype: float64, cumulative_returns=Date
#  2022-03-18    0.019121
#  2022-03-19    0.030306
#  2022-03-20    0.006700
#  2022-03-21    0.001712
#  2022-03-22    0.032678
#  2022-03-23    0.047353
#  2022-03-24    0.076223
#  2022-03-25    0.083840
#  2022-03-26    0.088599
#  2022-03-27    0.145709
#  2022-03-28    0.151926
#  2022-03-29    0.161848
#  2022-03-30    0.157291
#  2022-03-31    0.122717
#  2022-04-01    0.143259
#  2022-04-02    0.132010
#  2022-04-03    0.147035
#  2022-04-04    0.149321
#  2022-04-05    0.122471
#  2022-04-06    0.062438
#  2022-04-07    0.071468
#  dtype: float64, weights=BTC    1.012557
#  ETH   -0.066572
#  SOL    0.054015
#  Name: weight, dtype: float64, turnover=1.1331432505089034, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 9, 'covariance_method': 'sample', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2022-03-17 00:00:00'), 'test_start': Timestamp('2022-03-18 00:00:00'), 'test_end': Timestamp('2022-04-07 00:00:00')}), BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2022-04-08 -0.027956 -0.012743 -0.075723
#  2022-04-09  0.011693  0.021880  0.028888
#  2022-04-10 -0.013428 -0.015344 -0.010891
#  2022-04-11 -0.063632 -0.071863 -0.110999
#  2022-04-12  0.015315  0.016546  0.039937
#  2022-04-13  0.025906  0.029029  0.016413
#  2022-04-14 -0.029908 -0.031566 -0.040896
#  2022-04-15  0.015474  0.006956  0.005977
#  2022-04-16 -0.003181  0.007035  0.009353
#  2022-04-17 -0.017503 -0.022502 -0.018068
#  2022-04-18  0.027929  0.021448  0.017417
#  2022-04-19  0.016571  0.015208  0.062878
#  2022-04-20 -0.003093 -0.008492 -0.028412
#  2022-04-21 -0.020472 -0.029328 -0.035270
#  2022-04-22 -0.019420 -0.007580 -0.011438
#  2022-04-23 -0.006381 -0.009013  0.001316
#  2022-04-24 -0.000442 -0.005235 -0.014975
#  2022-04-25  0.025058  0.029651  0.020273
#  2022-04-26 -0.057858 -0.066823 -0.053981
#  2022-04-27  0.029479  0.028712  0.027111
#  2022-04-28  0.013575  0.016619 -0.001963, portfolio_returns=Date
#  2022-04-08   -0.031494
#  2022-04-09    0.011887
#  2022-04-10   -0.013163
#  2022-04-11   -0.065533
#  2022-04-12    0.016513
#  2022-04-13    0.025196
#  2022-04-14   -0.030366
#  2022-04-15    0.015566
#  2022-04-16   -0.003232
#  2022-04-17   -0.017187
#  2022-04-18    0.027828
#  2022-04-19    0.019079
#  2022-04-20   -0.004040
#  2022-04-21   -0.020633
#  2022-04-22   -0.019820
#  2022-04-23   -0.005799
#  2022-04-24   -0.000869
#  2022-04-25    0.024492
#  2022-04-26   -0.057038
#  2022-04-27    0.029408
#  2022-04-28    0.012556
#  dtype: float64, cumulative_returns=Date
#  2022-04-08   -0.031494
#  2022-04-09   -0.019982
#  2022-04-10   -0.032882
#  2022-04-11   -0.096261
#  2022-04-12   -0.081337
#  2022-04-13   -0.058190
#  2022-04-14   -0.086789
#  2022-04-15   -0.072574
#  2022-04-16   -0.075571
#  2022-04-17   -0.091460
#  2022-04-18   -0.066177
#  2022-04-19   -0.048361
#  2022-04-20   -0.052206
#  2022-04-21   -0.071761
#  2022-04-22   -0.090159
#  2022-04-23   -0.095435
#  2022-04-24   -0.096221
#  2022-04-25   -0.074086
#  2022-04-26   -0.126898
#  2022-04-27   -0.101221
#  2022-04-28   -0.089937
#  dtype: float64, weights=BTC    1.016832
#  ETH   -0.068950
#  SOL    0.052118
#  Name: weight, dtype: float64, turnover=1.1378994951664683, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 10, 'covariance_method': 'sample', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2022-04-07 00:00:00'), 'test_start': Timestamp('2022-04-08 00:00:00'), 'test_end': Timestamp('2022-04-28 00:00:00')}), BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2022-04-29 -0.029266 -0.041315 -0.042515
#  2022-04-30 -0.023179 -0.030336 -0.094833
#  2022-05-01  0.019998  0.035737  0.053770
#  2022-05-02  0.001566  0.010487 -0.023313
#  2022-05-03 -0.020215 -0.025875 -0.019852
#  2022-05-04  0.051600  0.056465  0.080712
#  2022-05-05 -0.078674 -0.065099 -0.088118
#  2022-05-06 -0.014606 -0.019727 -0.033476
#  2022-05-07 -0.014954 -0.021851 -0.034009
#  2022-05-08 -0.040637 -0.045003 -0.047646
#  2022-05-09 -0.110464 -0.108057 -0.158874
#  2022-05-10  0.023961  0.043680  0.055263
#  2022-05-11 -0.067258 -0.115810 -0.247960
#  2022-05-12  0.003850 -0.053282 -0.110081
#  2022-05-13  0.008102  0.026873  0.087503
#  2022-05-14  0.027940  0.020778  0.078687
#  2022-05-15  0.039993  0.043493  0.121983
#  2022-05-16 -0.046069 -0.057315 -0.087820
#  2022-05-17  0.018851  0.033461  0.064854
#  2022-05-18 -0.056057 -0.083119 -0.129004
#  2022-05-19  0.055503  0.053051  0.049396, portfolio_returns=Date
#  2022-04-29   -0.029088
#  2022-04-30   -0.026217
#  2022-05-01    0.020577
#  2022-05-02   -0.000275
#  2022-05-03   -0.019807
#  2022-05-04    0.052699
#  2022-05-05   -0.080076
#  2022-05-06   -0.015183
#  2022-05-07   -0.015418
#  2022-05-08   -0.040681
#  2022-05-09   -0.113015
#  2022-05-10    0.024144
#  2022-05-11   -0.072814
#  2022-05-12    0.002175
#  2022-05-13    0.010720
#  2022-05-14    0.030934
#  2022-05-15    0.043792
#  2022-05-16   -0.047351
#  2022-05-17    0.020110
#  2022-05-18   -0.057785
#  2022-05-19    0.055371
#  dtype: float64, cumulative_returns=Date
#  2022-04-29   -0.029088
#  2022-04-30   -0.054542
#  2022-05-01   -0.035087
#  2022-05-02   -0.035353
#  2022-05-03   -0.054460
#  2022-05-04   -0.004631
#  2022-05-05   -0.084335
#  2022-05-06   -0.098238
#  2022-05-07   -0.112141
#  2022-05-08   -0.148260
#  2022-05-09   -0.244519
#  2022-05-10   -0.226279
#  2022-05-11   -0.282617
#  2022-05-12   -0.281057
#  2022-05-13   -0.273349
#  2022-05-14   -0.250871
#  2022-05-15   -0.218065
#  2022-05-16   -0.255090
#  2022-05-17   -0.240110
#  2022-05-18   -0.284021
#  2022-05-19   -0.244376
#  dtype: float64, weights=BTC    1.019682
#  ETH   -0.068957
#  SOL    0.049275
#  Name: weight, dtype: float64, turnover=1.1379149757090978, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 11, 'covariance_method': 'sample', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2022-04-28 00:00:00'), 'test_start': Timestamp('2022-04-29 00:00:00'), 'test_end': Timestamp('2022-05-19 00:00:00')}), BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2022-05-20 -0.036735 -0.028251 -0.051240
#  2022-05-21  0.007927  0.006732  0.015735
#  2022-05-22  0.030290  0.034769  0.048436
#  2022-05-23 -0.040391 -0.034744 -0.070104
#  2022-05-24  0.019130  0.003448  0.012159
#  2022-05-25 -0.003144 -0.017259 -0.033652
#  2022-05-26 -0.009984 -0.072456 -0.093601
#  2022-05-27 -0.021856 -0.043788 -0.057710
#  2022-05-28  0.006544  0.019142  0.082033
#  2022-05-29  0.021900  0.030769  0.012774
#  2022-05-30  0.077445  0.101770  0.050542
#  2022-05-31  0.002078 -0.027105 -0.029920
#  2022-06-01 -0.062695 -0.061142 -0.120132
#  2022-06-02  0.022430  0.005802  0.015438
#  2022-06-03 -0.025046 -0.032207 -0.064369
#  2022-06-04  0.004327  0.014946  0.017570
#  2022-06-05  0.002472  0.001996 -0.011582
#  2022-06-06  0.048953  0.029960  0.102717
#  2022-06-07 -0.006860 -0.024333 -0.070595
#  2022-06-08 -0.030207 -0.011288 -0.015067
#  2022-06-09 -0.003388 -0.002089  0.029072, portfolio_returns=Date
#  2022-05-20   -0.037810
#  2022-05-21    0.008268
#  2022-05-22    0.030570
#  2022-05-23   -0.041766
#  2022-05-24    0.020008
#  2022-05-25   -0.003150
#  2022-05-26   -0.008324
#  2022-05-27   -0.021486
#  2022-05-28    0.008136
#  2022-05-29    0.020975
#  2022-05-30    0.074844
#  2022-05-31    0.003085
#  2022-06-01   -0.064693
#  2022-06-02    0.023374
#  2022-06-03   -0.025834
#  2022-06-04    0.004013
#  2022-06-05    0.002044
#  2022-06-06    0.052060
#  2022-06-07   -0.007722
#  2022-06-08   -0.031045
#  2022-06-09   -0.002412
#  dtype: float64, cumulative_returns=Date
#  2022-05-20   -0.037810
#  2022-05-21   -0.029855
#  2022-05-22   -0.000197
#  2022-05-23   -0.041955
#  2022-05-24   -0.022787
#  2022-05-25   -0.025865
#  2022-05-26   -0.033974
#  2022-05-27   -0.054730
#  2022-05-28   -0.047040
#  2022-05-29   -0.027052
#  2022-05-30    0.045768
#  2022-05-31    0.048994
#  2022-06-01   -0.018868
#  2022-06-02    0.004064
#  2022-06-03   -0.021874
#  2022-06-04   -0.017949
#  2022-06-05   -0.015942
#  2022-06-06    0.035288
#  2022-06-07    0.027294
#  2022-06-08   -0.004598
#  2022-06-09   -0.007000
#  dtype: float64, weights=BTC    1.037692
#  ETH   -0.070563
#  SOL    0.032871
#  Name: weight, dtype: float64, turnover=1.141126338234543, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 12, 'covariance_method': 'sample', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2022-05-19 00:00:00'), 'test_start': Timestamp('2022-05-20 00:00:00'), 'test_end': Timestamp('2022-06-09 00:00:00')}), BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2022-06-10 -0.034146 -0.069718 -0.072120
#  2022-06-11 -0.024859 -0.081307 -0.088128
#  2022-06-12 -0.056351 -0.055206 -0.091004
#  2022-06-13 -0.159747 -0.166504 -0.082975
#  2022-06-14 -0.012478  0.005878  0.053995
#  2022-06-15  0.016484  0.017780  0.160639
#  2022-06-16 -0.097072 -0.134183 -0.130428
#  2022-06-17  0.004407  0.017597  0.025115
#  2022-06-18 -0.071018 -0.085486  0.034643
#  2022-06-19  0.080748  0.134878  0.076579
#  2022-06-20  0.002251 -0.000012  0.034265
#  2022-06-21  0.005391 -0.002499  0.019879
#  2022-06-22 -0.034937 -0.065257 -0.055356
#  2022-06-23  0.054978  0.087467  0.118798
#  2022-06-24  0.006914  0.072992  0.105744
#  2022-06-25  0.012749  0.013532  0.002861
#  2022-06-26 -0.022093 -0.035076 -0.069089
#  2022-06-27 -0.013878 -0.005127 -0.024280
#  2022-06-28 -0.021936 -0.041134 -0.081267
#  2022-06-29 -0.008708 -0.039871 -0.041118
#  2022-06-30 -0.015882 -0.028796 -0.008428, portfolio_returns=Date
#  2022-06-10   -0.032789
#  2022-06-11   -0.022793
#  2022-06-12   -0.057422
#  2022-06-13   -0.157085
#  2022-06-14   -0.011836
#  2022-06-15    0.020522
#  2022-06-16   -0.095477
#  2022-06-17    0.004094
#  2022-06-18   -0.066998
#  2022-06-19    0.076909
#  2022-06-20    0.003323
#  2022-06-21    0.006348
#  2022-06-22   -0.033439
#  2022-06-23    0.054573
#  2022-06-24    0.005204
#  2022-06-25    0.012412
#  2022-06-26   -0.022546
#  2022-06-27   -0.014777
#  2022-06-28   -0.022315
#  2022-06-29   -0.007495
#  2022-06-30   -0.014782
#  dtype: float64, cumulative_returns=Date
#  2022-06-10   -0.032789
#  2022-06-11   -0.054834
#  2022-06-12   -0.109108
#  2022-06-13   -0.249053
#  2022-06-14   -0.257941
#  2022-06-15   -0.242713
#  2022-06-16   -0.315017
#  2022-06-17   -0.312212
#  2022-06-18   -0.358293
#  2022-06-19   -0.308939
#  2022-06-20   -0.306643
#  2022-06-21   -0.302241
#  2022-06-22   -0.325573
#  2022-06-23   -0.288768
#  2022-06-24   -0.285067
#  2022-06-25   -0.276193
#  2022-06-26   -0.292512
#  2022-06-27   -0.302967
#  2022-06-28   -0.318521
#  2022-06-29   -0.323629
#  2022-06-30   -0.333627
#  dtype: float64, weights=BTC    1.040067
#  ETH   -0.068700
#  SOL    0.028633
#  Name: weight, dtype: float64, turnover=1.1374001850121127, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 13, 'covariance_method': 'sample', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2022-06-09 00:00:00'), 'test_start': Timestamp('2022-06-10 00:00:00'), 'test_end': Timestamp('2022-06-30 00:00:00')}), BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2022-07-01 -0.026048 -0.007057 -0.023381
#  2022-07-02 -0.001407  0.006365  0.016960
#  2022-07-03  0.002849  0.006802  0.000795
#  2022-07-04  0.048411  0.071982  0.101812
#  2022-07-05 -0.002034 -0.014350 -0.037773
#  2022-07-06  0.017738  0.046215  0.047407
#  2022-07-07  0.053014  0.042646  0.038970
#  2022-07-08  0.004323 -0.012191 -0.006012
#  2022-07-09 -0.006392 -0.004522 -0.005609
#  2022-07-10 -0.033890 -0.039916 -0.036099
#  2022-07-11 -0.042659 -0.060908 -0.088126
#  2022-07-12 -0.032380 -0.053812 -0.021098
#  2022-07-13  0.045962  0.072622  0.065736
#  2022-07-14  0.017705  0.069989  0.062928
#  2022-07-15  0.012951  0.034916  0.008303
#  2022-07-16  0.016989  0.096906  0.057681
#  2022-07-17 -0.019394 -0.010343 -0.023485
#  2022-07-18  0.082117  0.179348  0.132009
#  2022-07-19  0.040192 -0.022640  0.026373
#  2022-07-20 -0.006742 -0.014760 -0.062499
#  2022-07-21 -0.002888  0.037198  0.026059, portfolio_returns=Date
#  2022-07-01   -0.027928
#  2022-07-02   -0.001588
#  2022-07-03    0.002369
#  2022-07-04    0.047782
#  2022-07-05   -0.001972
#  2022-07-06    0.015793
#  2022-07-07    0.053612
#  2022-07-08    0.005684
#  2022-07-09   -0.006560
#  2022-07-10   -0.033340
#  2022-07-11   -0.042313
#  2022-07-12   -0.029772
#  2022-07-13    0.043868
#  2022-07-14    0.013818
#  2022-07-15    0.010514
#  2022-07-16    0.010081
#  2022-07-17   -0.020473
#  2022-07-18    0.073726
#  2022-07-19    0.046242
#  2022-07-20   -0.007808
#  2022-07-21   -0.006063
#  dtype: float64, cumulative_returns=Date
#  2022-07-01   -0.027928
#  2022-07-02   -0.029472
#  2022-07-03   -0.027173
#  2022-07-04    0.019310
#  2022-07-05    0.017300
#  2022-07-06    0.033366
#  2022-07-07    0.088767
#  2022-07-08    0.094956
#  2022-07-09    0.087773
#  2022-07-10    0.051507
#  2022-07-11    0.007015
#  2022-07-12   -0.022966
#  2022-07-13    0.019895
#  2022-07-14    0.033988
#  2022-07-15    0.044859
#  2022-07-16    0.055392
#  2022-07-17    0.033785
#  2022-07-18    0.110002
#  2022-07-19    0.161330
#  2022-07-20    0.152263
#  2022-07-21    0.145276
#  dtype: float64, weights=BTC    1.069738
#  ETH   -0.103768
#  SOL    0.034030
#  Name: weight, dtype: float64, turnover=1.2075366971580996, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 14, 'covariance_method': 'sample', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2022-06-30 00:00:00'), 'test_start': Timestamp('2022-07-01 00:00:00'), 'test_end': Timestamp('2022-07-21 00:00:00')}), BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2022-07-22 -0.019411 -0.024953 -0.059552
#  2022-07-23 -0.010984  0.007735 -0.014218
#  2022-07-24  0.006396  0.032388  0.024115
#  2022-07-25 -0.055175 -0.096340 -0.104729
#  2022-07-26 -0.005709 -0.002475 -0.014195
#  2022-07-27  0.079605  0.134849  0.113758
#  2022-07-28  0.039831  0.054537  0.062951
#  2022-07-29 -0.001646  0.001124 -0.021432
#  2022-07-30 -0.006235 -0.018199  0.043621
#  2022-07-31 -0.013498 -0.008521 -0.030983
#  2022-08-01 -0.000973 -0.027547 -0.014474
#  2022-08-02 -0.014415 -0.001376 -0.048628
#  2022-08-03 -0.005728 -0.008617 -0.030439
#  2022-08-04 -0.009435 -0.006590  0.007427
#  2022-08-05  0.029091  0.077135  0.044562
#  2022-08-06 -0.014085 -0.023436 -0.012426
#  2022-08-07  0.009347  0.004547  0.013695
#  2022-08-08  0.027339  0.044820  0.038541
#  2022-08-09 -0.027097 -0.040828 -0.042635
#  2022-08-10  0.033816  0.087326  0.049371
#  2022-08-11  0.000413  0.015921  0.010762, portfolio_returns=Date
#  2022-07-22   -0.020099
#  2022-07-23   -0.013300
#  2022-07-24    0.003922
#  2022-07-25   -0.051975
#  2022-07-26   -0.006374
#  2022-07-27    0.074230
#  2022-07-28    0.038868
#  2022-07-29   -0.002634
#  2022-07-30   -0.003158
#  2022-07-31   -0.014669
#  2022-08-01    0.001711
#  2022-08-02   -0.017097
#  2022-08-03   -0.006213
#  2022-08-04   -0.009207
#  2022-08-05    0.023941
#  2022-08-06   -0.012927
#  2022-08-07    0.010058
#  2022-08-08    0.025651
#  2022-08-09   -0.025997
#  2022-08-10    0.028024
#  2022-08-11   -0.001071
#  dtype: float64, cumulative_returns=Date
#  2022-07-22   -0.020099
#  2022-07-23   -0.033132
#  2022-07-24   -0.029340
#  2022-07-25   -0.079790
#  2022-07-26   -0.085655
#  2022-07-27   -0.017784
#  2022-07-28    0.020394
#  2022-07-29    0.017706
#  2022-07-30    0.014492
#  2022-07-31   -0.000390
#  2022-08-01    0.001320
#  2022-08-02   -0.015799
#  2022-08-03   -0.021913
#  2022-08-04   -0.030918
#  2022-08-05   -0.007718
#  2022-08-06   -0.020545
#  2022-08-07   -0.010694
#  2022-08-08    0.014683
#  2022-08-09   -0.011695
#  2022-08-10    0.016001
#  2022-08-11    0.014913
#  dtype: float64, weights=BTC    1.084545
#  ETH   -0.117963
#  SOL    0.033418
#  Name: weight, dtype: float64, turnover=1.2359254277793656, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 15, 'covariance_method': 'sample', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2022-07-21 00:00:00'), 'test_start': Timestamp('2022-07-22 00:00:00'), 'test_end': Timestamp('2022-08-11 00:00:00')}), BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2022-08-12  0.018587  0.040411  0.058684
#  2022-08-13  0.000871  0.012308  0.025380
#  2022-08-14 -0.004288 -0.022477 -0.033748
#  2022-08-15 -0.007499 -0.016818 -0.024342
#  2022-08-16 -0.010510 -0.013700 -0.015161
#  2022-08-17 -0.022915 -0.024034 -0.063851
#  2022-08-18 -0.005282  0.007642 -0.021232
#  2022-08-19 -0.100599 -0.126703 -0.092425
#  2022-08-20  0.013819 -0.022309 -0.017290
#  2022-08-21  0.017389  0.026833  0.035823
#  2022-08-22 -0.006279  0.001968 -0.028982
#  2022-08-23  0.006037  0.024816  0.004845
#  2022-08-24 -0.006181 -0.003434 -0.019310
#  2022-08-25  0.009623  0.023776  0.010257
#  2022-08-26 -0.062075 -0.111217 -0.101655
#  2022-08-27 -0.010774 -0.010869 -0.005797
#  2022-08-28 -0.021202 -0.040799 -0.036463
#  2022-08-29  0.034724  0.085625  0.068208
#  2022-08-30 -0.024691 -0.018801 -0.032442
#  2022-08-31  0.012778  0.019586  0.001939
#  2022-09-01  0.003859  0.020913  0.003582, portfolio_returns=Date
#  2022-08-12    0.016971
#  2022-08-13    0.000138
#  2022-08-14   -0.002812
#  2022-08-15   -0.006799
#  2022-08-16   -0.010234
#  2022-08-17   -0.024104
#  2022-08-18   -0.007537
#  2022-08-19   -0.096830
#  2022-08-20    0.017648
#  2022-08-21    0.016725
#  2022-08-22   -0.008128
#  2022-08-23    0.003479
#  2022-08-24   -0.006979
#  2022-08-25    0.007745
#  2022-08-26   -0.056778
#  2022-08-27   -0.010598
#  2022-08-28   -0.019072
#  2022-08-29    0.028992
#  2022-08-30   -0.025735
#  2022-08-31    0.011510
#  2022-09-01    0.001563
#  dtype: float64, cumulative_returns=Date
#  2022-08-12    0.016971
#  2022-08-13    0.017111
#  2022-08-14    0.014251
#  2022-08-15    0.007355
#  2022-08-16   -0.002955
#  2022-08-17   -0.026988
#  2022-08-18   -0.034322
#  2022-08-19   -0.127829
#  2022-08-20   -0.112437
#  2022-08-21   -0.097592
#  2022-08-22   -0.104927
#  2022-08-23   -0.101813
#  2022-08-24   -0.108081
#  2022-08-25   -0.101173
#  2022-08-26   -0.152207
#  2022-08-27   -0.161192
#  2022-08-28   -0.177190
#  2022-08-29   -0.153336
#  2022-08-30   -0.175125
#  2022-08-31   -0.165631
#  2022-09-01   -0.164327
#  dtype: float64, weights=BTC    1.101432
#  ETH   -0.134142
#  SOL    0.032710
#  Name: weight, dtype: float64, turnover=1.2682830575172617, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 16, 'covariance_method': 'sample', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2022-08-11 00:00:00'), 'test_start': Timestamp('2022-08-12 00:00:00'), 'test_end': Timestamp('2022-09-01 00:00:00')}), BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2022-09-02 -0.007819 -0.005646 -0.011326
#  2022-09-03 -0.006895 -0.012901 -0.003793
#  2022-09-04  0.007797  0.013340  0.032063
#  2022-09-05 -0.008723  0.025064  0.002731
#  2022-09-06 -0.049197 -0.034279 -0.040470
#  2022-09-07  0.024029  0.043642  0.058889
#  2022-09-08  0.002048  0.003338  0.027444
#  2022-09-09  0.106122  0.051205  0.033656
#  2022-09-10  0.014002  0.033226  0.011139
#  2022-09-11  0.004092 -0.008109 -0.004577
#  2022-09-12  0.027617 -0.027265  0.070303
#  2022-09-13 -0.092700 -0.077594 -0.106706
#  2022-09-14 -0.002740  0.034139  0.019765
#  2022-09-15 -0.026672 -0.099747 -0.030620
#  2022-09-16  0.003623 -0.026667 -0.025382
#  2022-09-17  0.017954  0.026035  0.047873
#  2022-09-18 -0.035179 -0.091453 -0.079729
#  2022-09-19  0.006417  0.031612  0.052333
#  2022-09-20 -0.033429 -0.038586 -0.038313
#  2022-09-21 -0.018178 -0.054199 -0.019300
#  2022-09-22  0.046699  0.059933  0.051337, portfolio_returns=Date
#  2022-09-02   -0.008252
#  2022-09-03   -0.005912
#  2022-09-04    0.007773
#  2022-09-05   -0.013308
#  2022-09-06   -0.051102
#  2022-09-07    0.022286
#  2022-09-08    0.002685
#  2022-09-09    0.111822
#  2022-09-10    0.011088
#  2022-09-11    0.005600
#  2022-09-12    0.037059
#  2022-09-13   -0.095373
#  2022-09-14   -0.007420
#  2022-09-15   -0.016078
#  2022-09-16    0.007124
#  2022-09-17    0.017742
#  2022-09-18   -0.028371
#  2022-09-19    0.004215
#  2022-09-20   -0.032831
#  2022-09-21   -0.012928
#  2022-09-22    0.044908
#  dtype: float64, cumulative_returns=Date
#  2022-09-02   -0.008252
#  2022-09-03   -0.014115
#  2022-09-04   -0.006452
#  2022-09-05   -0.019674
#  2022-09-06   -0.069770
#  2022-09-07   -0.049039
#  2022-09-08   -0.046486
#  2022-09-09    0.060138
#  2022-09-10    0.071893
#  2022-09-11    0.077896
#  2022-09-12    0.117842
#  2022-09-13    0.011231
#  2022-09-14    0.003728
#  2022-09-15   -0.012410
#  2022-09-16   -0.005375
#  2022-09-17    0.012271
#  2022-09-18   -0.016448
#  2022-09-19   -0.012303
#  2022-09-20   -0.044730
#  2022-09-21   -0.057080
#  2022-09-22   -0.014735
#  dtype: float64, weights=BTC    1.114196
#  ETH   -0.146741
#  SOL    0.032545
# ...
#  2025-08-12  0.012141  0.086104  0.096464
#  2025-08-13  0.026388  0.036017  0.050734
#  2025-08-14 -0.040411 -0.043755 -0.044667
#  2025-08-15 -0.008121 -0.023785 -0.035541
#  2025-08-16  0.000792 -0.003110  0.021674
#  2025-08-17 -0.000326  0.010639  0.007366
#  2025-08-18 -0.010223 -0.035939 -0.042345
#  2025-08-19 -0.029429 -0.055430 -0.038005
#  2025-08-20  0.012794  0.064082  0.065152
#  2025-08-21 -0.016239 -0.025676 -0.038946
#  2025-08-22  0.039629  0.143999  0.112973
#  2025-08-23 -0.012832 -0.011437  0.016393
#  2025-08-24 -0.016606  0.000745  0.009393
#  2025-08-25 -0.029386 -0.085082 -0.090229
#  2025-08-26  0.015240  0.052010  0.046063
#  2025-08-27 -0.005193 -0.021092  0.035825
#  2025-08-28  0.011893  0.000840  0.056584, portfolio_returns=Date
#  2025-08-08   -0.003045
#  2025-08-09    0.008041
#  2025-08-10    0.020279
#  2025-08-11    0.002622
#  2025-08-12    0.010929
#  2025-08-13    0.023529
#  2025-08-14   -0.040267
#  2025-08-15   -0.005932
#  2025-08-16   -0.004264
#  2025-08-17    0.000466
#  2025-08-18   -0.009235
#  2025-08-19   -0.033260
#  2025-08-20    0.013190
#  2025-08-21   -0.013670
#  2025-08-22    0.047145
#  2025-08-23   -0.018441
#  2025-08-24   -0.018147
#  2025-08-25   -0.029010
#  2025-08-26    0.016881
#  2025-08-27   -0.016886
#  2025-08-28    0.000494
#  dtype: float64, cumulative_returns=Date
#  2025-08-08   -0.003045
#  2025-08-09    0.004972
#  2025-08-10    0.025351
#  2025-08-11    0.028040
#  2025-08-12    0.039275
#  2025-08-13    0.063728
#  2025-08-14    0.020895
#  2025-08-15    0.014839
#  2025-08-16    0.010512
#  2025-08-17    0.010984
#  2025-08-18    0.001647
#  2025-08-19   -0.031668
#  2025-08-20   -0.018896
#  2025-08-21   -0.032307
#  2025-08-22    0.013314
#  2025-08-23   -0.005372
#  2025-08-24   -0.023421
#  2025-08-25   -0.051752
#  2025-08-26   -0.035745
#  2025-08-27   -0.052027
#  2025-08-28   -0.051559
#  dtype: float64, weights=BTC    0.988070
#  ETH    0.214043
#  SOL   -0.202113
#  Name: weight, dtype: float64, turnover=1.4042261415940867, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 68, 'covariance_method': 'ledoit_wolf', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2025-08-07 00:00:00'), 'test_start': Timestamp('2025-08-08 00:00:00'), 'test_end': Timestamp('2025-08-28 00:00:00')}), BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2025-08-29 -0.036732 -0.032620 -0.042842
#  2025-08-30  0.003664  0.003211 -0.011499
#  2025-08-31 -0.005251  0.003627 -0.009842
#  2025-09-01  0.009367 -0.017209 -0.018695
#  2025-09-02  0.017849  0.002525  0.062774
#  2025-09-03  0.004700  0.028905  0.006038
#  2025-09-04 -0.008947 -0.034075 -0.038844
#  2025-09-05 -0.000656  0.001918  0.004632
#  2025-09-06 -0.003853 -0.007603 -0.015982
#  2025-09-07  0.008555  0.007277  0.031071
#  2025-09-08  0.008130  0.000633  0.037382
#  2025-09-09 -0.004826  0.000225  0.014307
#  2025-09-10  0.021741  0.009307  0.031007
#  2025-09-11  0.013621  0.025772  0.021293
#  2025-09-12  0.005143  0.056938  0.059221
#  2025-09-13 -0.001301 -0.009982  0.001208
#  2025-09-14 -0.004682 -0.012549 -0.008402
#  2025-09-15  0.000322 -0.017958 -0.025774
#  2025-09-16  0.012112 -0.005137  0.011231
#  2025-09-17 -0.003207  0.019800  0.033199
#  2025-09-18  0.005741 -0.000613  0.011352, portfolio_returns=Date
#  2025-08-29   -0.034657
#  2025-08-30    0.006624
#  2025-08-31   -0.002503
#  2025-09-01    0.009559
#  2025-09-02    0.005655
#  2025-09-03    0.009403
#  2025-09-04   -0.008089
#  2025-09-05   -0.001192
#  2025-09-06   -0.002181
#  2025-09-07    0.003758
#  2025-09-08    0.000700
#  2025-09-09   -0.007641
#  2025-09-10    0.017321
#  2025-09-11    0.014572
#  2025-09-12    0.004893
#  2025-09-13   -0.003590
#  2025-09-14   -0.005549
#  2025-09-15    0.001822
#  2025-09-16    0.008746
#  2025-09-17   -0.005811
#  2025-09-18    0.003306
#  dtype: float64, cumulative_returns=Date
#  2025-08-29   -0.034657
#  2025-08-30   -0.028262
#  2025-08-31   -0.030694
#  2025-09-01   -0.021429
#  2025-09-02   -0.015895
#  2025-09-03   -0.006642
#  2025-09-04   -0.014677
#  2025-09-05   -0.015851
#  2025-09-06   -0.017998
#  2025-09-07   -0.014307
#  2025-09-08   -0.013617
#  2025-09-09   -0.021155
#  2025-09-10   -0.004200
#  2025-09-11    0.010311
#  2025-09-12    0.015255
#  2025-09-13    0.011611
#  2025-09-14    0.005998
#  2025-09-15    0.007831
#  2025-09-16    0.016646
#  2025-09-17    0.010737
#  2025-09-18    0.014079
#  dtype: float64, weights=BTC    0.995941
#  ETH    0.205423
#  SOL   -0.201364
#  Name: weight, dtype: float64, turnover=1.4027277987365814, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 69, 'covariance_method': 'ledoit_wolf', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2025-08-28 00:00:00'), 'test_start': Timestamp('2025-08-29 00:00:00'), 'test_end': Timestamp('2025-09-18 00:00:00')}), BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2025-09-19 -0.012365 -0.025927 -0.036684
#  2025-09-20  0.000286  0.002538  0.004359
#  2025-09-21 -0.003594 -0.006902 -0.012592
#  2025-09-22 -0.022181 -0.055815 -0.067966
#  2025-09-23 -0.006510 -0.008892 -0.030745
#  2025-09-24  0.011732 -0.002889 -0.009176
#  2025-09-25 -0.037760 -0.068650 -0.091499
#  2025-09-26  0.006085  0.043314  0.067428
#  2025-09-27 -0.000281 -0.004269 -0.008616
#  2025-09-28  0.022252  0.030562  0.035142
#  2025-09-29  0.020315  0.018318  0.010988
#  2025-09-30 -0.003010 -0.016926 -0.020231
#  2025-10-01  0.040268  0.049483  0.061955
#  2025-10-02  0.017129  0.031443  0.059461
#  2025-10-03  0.013136  0.006004 -0.007898
#  2025-10-04  0.001300 -0.005686 -0.021454
#  2025-10-05  0.008887  0.005842  0.002623
#  2025-10-06  0.010032  0.038169  0.017125
#  2025-10-07 -0.026462 -0.050476 -0.051753
#  2025-10-08  0.015673  0.017186  0.039089
#  2025-10-09 -0.013370 -0.035008 -0.035400, portfolio_returns=Date
#  2025-09-19   -0.010250
#  2025-09-20   -0.000072
#  2025-09-21   -0.002461
#  2025-09-22   -0.019860
#  2025-09-23   -0.002122
#  2025-09-24    0.012943
#  2025-09-25   -0.033277
#  2025-09-26    0.001370
#  2025-09-27    0.000578
#  2025-09-28    0.021362
#  2025-09-29    0.021782
#  2025-09-30   -0.002396
#  2025-10-01    0.037793
#  2025-10-02    0.011545
#  2025-10-03    0.015907
#  2025-10-04    0.004446
#  2025-10-05    0.009524
#  2025-10-06    0.014369
#  2025-10-07   -0.026293
#  2025-10-08    0.011271
#  2025-10-09   -0.013371
#  dtype: float64, cumulative_returns=Date
#  2025-09-19   -0.010250
#  2025-09-20   -0.010321
#  2025-09-21   -0.012757
#  2025-09-22   -0.032363
#  2025-09-23   -0.034417
#  2025-09-24   -0.021920
#  2025-09-25   -0.054467
#  2025-09-26   -0.053172
#  2025-09-27   -0.052624
#  2025-09-28   -0.032387
#  2025-09-29   -0.011310
#  2025-09-30   -0.013679
#  2025-10-01    0.023597
#  2025-10-02    0.035414
#  2025-10-03    0.051884
#  2025-10-04    0.056561
#  2025-10-05    0.066624
#  2025-10-06    0.081951
#  2025-10-07    0.053503
#  2025-10-08    0.065377
#  2025-10-09    0.051132
#  dtype: float64, weights=BTC    0.996317
#  ETH    0.204881
#  SOL   -0.201198
#  Name: weight, dtype: float64, turnover=1.4023965368433924, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 70, 'covariance_method': 'ledoit_wolf', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2025-09-18 00:00:00'), 'test_start': Timestamp('2025-09-19 00:00:00'), 'test_end': Timestamp('2025-10-09 00:00:00')}), BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2025-10-10 -0.069769 -0.120421 -0.146283
#  2025-10-11 -0.021256 -0.024043 -0.056236
#  2025-10-12  0.039364  0.110333  0.109261
#  2025-10-13  0.000880  0.019460  0.054979
#  2025-10-14 -0.018673 -0.028279 -0.028349
#  2025-10-15 -0.020646 -0.033440 -0.041680
#  2025-10-16 -0.023443 -0.023249 -0.048102
#  2025-10-17 -0.015882 -0.015969 -0.014371
#  2025-10-18  0.006861  0.015078  0.030903
#  2025-10-19  0.013698  0.024240  0.000735
#  2025-10-20  0.017689 -0.000976  0.010397
#  2025-10-21 -0.019098 -0.026125 -0.021525
#  2025-10-22 -0.007267 -0.017706 -0.029721
#  2025-10-23  0.022111  0.012579  0.062394
#  2025-10-24  0.008760  0.020368  0.011348
#  2025-10-25  0.005474  0.004804  0.002481
#  2025-10-26  0.025355  0.051731  0.030861
#  2025-10-27 -0.003085 -0.009107 -0.006434
#  2025-10-28 -0.010193 -0.033460 -0.021631
#  2025-10-29 -0.025681 -0.019815 -0.000164
#  2025-10-30 -0.015899 -0.025357 -0.050339, portfolio_returns=Date
#  2025-10-10   -0.064551
#  2025-10-11   -0.014742
#  2025-10-12    0.039604
#  2025-10-13   -0.006302
#  2025-10-14   -0.018662
#  2025-10-15   -0.018983
#  2025-10-16   -0.018414
#  2025-10-17   -0.016206
#  2025-10-18    0.003661
#  2025-10-19    0.018459
#  2025-10-20    0.015382
#  2025-10-21   -0.020031
#  2025-10-22   -0.004839
#  2025-10-23    0.012027
#  2025-10-24    0.010589
#  2025-10-25    0.005944
#  2025-10-26    0.029587
#  2025-10-27   -0.003628
#  2025-10-28   -0.012594
#  2025-10-29   -0.029656
#  2025-10-30   -0.010846
#  dtype: float64, cumulative_returns=Date
#  2025-10-10   -0.064551
#  2025-10-11   -0.078341
#  2025-10-12   -0.041840
#  2025-10-13   -0.047878
#  2025-10-14   -0.065646
#  2025-10-15   -0.083383
#  2025-10-16   -0.100262
#  2025-10-17   -0.114843
#  2025-10-18   -0.111602
#  2025-10-19   -0.095203
#  2025-10-20   -0.081286
#  2025-10-21   -0.099689
#  2025-10-22   -0.104046
#  2025-10-23   -0.093270
#  2025-10-24   -0.083668
#  2025-10-25   -0.078222
#  2025-10-26   -0.050949
#  2025-10-27   -0.054391
#  2025-10-28   -0.066300
#  2025-10-29   -0.093990
#  2025-10-30   -0.103817
#  dtype: float64, weights=BTC    0.999678
#  ETH    0.202694
#  SOL   -0.202371
#  Name: weight, dtype: float64, turnover=1.4047429242830125, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 71, 'covariance_method': 'ledoit_wolf', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2025-10-09 00:00:00'), 'test_start': Timestamp('2025-10-10 00:00:00'), 'test_end': Timestamp('2025-10-30 00:00:00')}), BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2025-10-31  0.011547  0.011225  0.014002
#  2025-11-01  0.004636  0.007046 -0.004430
#  2025-11-02  0.005230  0.009518  0.007758
#  2025-11-03 -0.036986 -0.078944 -0.115720
#  2025-11-04 -0.046524 -0.085982 -0.064347
#  2025-11-05  0.022653  0.040271  0.046092
#  2025-11-06 -0.024935 -0.032966 -0.046136
#  2025-11-07  0.020445  0.037148  0.042835
#  2025-11-08 -0.010547 -0.010167 -0.022297
#  2025-11-09  0.023831  0.053596  0.040172
#  2025-11-10  0.012194 -0.003953  0.017714
#  2025-11-11 -0.028295 -0.042925 -0.076471
#  2025-11-12 -0.012955 -0.000641 -0.008451
#  2025-11-13 -0.019335 -0.052837 -0.053200
#  2025-11-14 -0.053158 -0.039895 -0.044325
#  2025-11-15  0.012197  0.020248  0.006191
#  2025-11-16 -0.014360 -0.023300 -0.016264
#  2025-11-17 -0.022120 -0.022086 -0.046752
#  2025-11-18  0.009284  0.032547  0.075401
#  2025-11-19 -0.015954 -0.031991 -0.028053
#  2025-11-20 -0.052851 -0.063278 -0.023762, portfolio_returns=Date
#  2025-10-31    0.010982
#  2025-11-01    0.006967
#  2025-11-02    0.005566
#  2025-11-03   -0.029243
#  2025-11-04   -0.050726
#  2025-11-05    0.021367
#  2025-11-06   -0.022201
#  2025-11-07    0.019191
#  2025-11-08   -0.008071
#  2025-11-09    0.026409
#  2025-11-10    0.007857
#  2025-11-11   -0.021362
#  2025-11-12   -0.011427
#  2025-11-13   -0.019077
#  2025-11-14   -0.052326
#  2025-11-15    0.015024
#  2025-11-16   -0.015748
#  2025-11-17   -0.017082
#  2025-11-18    0.000402
#  2025-11-19   -0.016670
#  2025-11-20   -0.060866
#  dtype: float64, cumulative_returns=Date
#  2025-10-31    0.010982
#  2025-11-01    0.018025
#  2025-11-02    0.023691
#  2025-11-03   -0.006245
#  2025-11-04   -0.056654
#  2025-11-05   -0.036497
#  2025-11-06   -0.057888
#  2025-11-07   -0.039807
#  2025-11-08   -0.047557
#  2025-11-09   -0.022404
#  2025-11-10   -0.014723
#  2025-11-11   -0.035770
#  2025-11-12   -0.046788
#  2025-11-13   -0.064972
#  2025-11-14   -0.113899
#  2025-11-15   -0.100586
#  2025-11-16   -0.114750
#  2025-11-17   -0.129871
#  2025-11-18   -0.129521
#  2025-11-19   -0.144032
#  2025-11-20   -0.196131
#  dtype: float64, weights=BTC    1.005505
#  ETH    0.198762
#  SOL   -0.204267
#  Name: weight, dtype: float64, turnover=1.408534956033506, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 72, 'covariance_method': 'ledoit_wolf', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2025-10-30 00:00:00'), 'test_start': Timestamp('2025-10-31 00:00:00'), 'test_end': Timestamp('2025-11-20 00:00:00')}), BacktestResult(asset_returns=                 BTC       ETH       SOL
#  Date
#  2025-11-21 -0.017790 -0.023335 -0.037573
#  2025-11-22 -0.005198  0.000690 -0.007388
#  2025-11-23  0.025478  0.012310  0.024726
#  2025-11-24  0.016883  0.053910  0.058653
#  2025-11-25 -0.010521  0.001769  0.003756
#  2025-11-26  0.036368  0.023623  0.029671
#  2025-11-27  0.008474 -0.004383 -0.015144
#  2025-11-28 -0.004011  0.005892 -0.024539
#  2025-11-29 -0.000743 -0.013395 -0.009524
#  2025-11-30 -0.005035  0.000143 -0.018495
#  2025-12-01 -0.045055 -0.064143 -0.051329
#  2025-12-02  0.058255  0.070620  0.094430
#  2025-12-03  0.023838  0.064588  0.044884
#  2025-12-04 -0.014821 -0.017940 -0.040608
#  2025-12-05 -0.029887 -0.035058 -0.040942
#  2025-12-06 -0.001291  0.005216 -0.007310
#  2025-12-07  0.012694  0.006938 -0.001926
#  2025-12-08  0.002595  0.020872  0.008968
#  2025-12-09  0.022634  0.062689  0.034690
#  2025-12-10 -0.007237  0.001287 -0.010388
#  2025-12-11  0.005329 -0.026563 -0.000714, portfolio_returns=Date
#  2025-11-21   -0.014805
#  2025-11-22   -0.003593
#  2025-11-23    0.023049
#  2025-11-24    0.015547
#  2025-11-25   -0.011049
#  2025-11-26    0.035247
#  2025-11-27    0.010814
#  2025-11-28    0.002158
#  2025-11-29   -0.001417
#  2025-11-30   -0.001248
#  2025-12-01   -0.047508
#  2025-12-02    0.053233
#  2025-12-03    0.027499
#  2025-12-04   -0.010124
#  2025-12-05   -0.028626
#  2025-12-06    0.001225
#  2025-12-07    0.014575
#  2025-12-08    0.004868
#  2025-12-09    0.028009
#  2025-12-10   -0.004916
#  2025-12-11    0.000317
#  dtype: float64, cumulative_returns=Date
#  2025-11-21   -0.014805
#  2025-11-22   -0.018345
#  2025-11-23    0.004282
#  2025-11-24    0.019896
#  2025-11-25    0.008626
#  2025-11-26    0.044178
#  2025-11-27    0.055469
#  2025-11-28    0.057747
#  2025-11-29    0.056248
#  2025-11-30    0.054930
#  2025-12-01    0.004813
#  2025-12-02    0.058301
#  2025-12-03    0.087403
#  2025-12-04    0.076394
#  2025-12-05    0.045582
#  2025-12-06    0.046862
#  2025-12-07    0.062120
#  2025-12-08    0.067290
#  2025-12-09    0.097184
#  2025-12-10    0.091790
#  2025-12-11    0.092137
#  dtype: float64, weights=BTC    1.009716
#  ETH    0.196156
#  SOL   -0.205872
#  Name: weight, dtype: float64, turnover=1.4117432266131795, transaction_costs=0.0, metadata={'engine': 'CARL', 'engine_component': 'backtest', 'version': '1.0', 'validation': 'walk_forward', 'out_of_sample': True, 'fold': 73, 'covariance_method': 'ledoit_wolf', 'shrinkage': None, 'portfolio_method': 'global_minimum_variance', 'train_start': Timestamp('2021-01-01 00:00:00'), 'train_end': Timestamp('2025-11-20 00:00:00'), 'test_start': Timestamp('2025-11-21 00:00:00'), 'test_end': Timestamp('2025-12-11 00:00:00')})), parameters={'method': 'ledoit_wolf', 'train_size': 252, 'test_size': 21, 'shrinkage': None, 'expanding': True}, metadata={'experiment': 'covariance_comparison', 'validation': 'walk_forward', 'out_of_sample': True, 'portfolio_method': 'global_minimum_variance', 'fold_count': 74})]

# %%
[(e.method, len(e.returns), len(e.folds)) for e in experiments]
# Out:
# [('sample', 1554, 74), ('shrinkage', 1554, 74), ('ledoit_wolf', 1554, 74)]

# %%
from crypto_alpha_lab.evaluation.covariance_comparison import (
    compare_covariance_methods,
)

comparison = compare_covariance_methods(
    experiments=experiments,
    periods_per_year=365,
    risk_free_rate=0.0,
)

# %%
decision_table = (
    comparison.summary[
        [
            "total_return",
            "annualized_return",
            "annualized_volatility",
            "sharpe_ratio",
            "sortino_ratio",
            "maximum_drawdown",
            "calmar_ratio",
            "average_turnover",
        ]
    ]
    .copy()
)

decision_table
# Out:
#              total_return  annualized_return  annualized_volatility  \
# method
# sample           0.869704           0.158333               0.525500
# shrinkage        0.781683           0.145287               0.523977
# ledoit_wolf      0.568794           0.111563               0.525942
#
#              sharpe_ratio  sortino_ratio  maximum_drawdown  calmar_ratio  \
# method
# sample           0.542223       0.041746         -0.781959      0.213557
# shrinkage        0.520786       0.039903         -0.767388      0.201527
# ledoit_wolf      0.464014       0.035355         -0.725831      0.168007
#
#              average_turnover
# method
# sample               1.219442
# shrinkage            1.110687
# ledoit_wolf          1.352342

# %%
leaders = pd.Series(
    {
        "total_return": decision_table[
            "total_return"
        ].idxmax(),

        "annualized_return": decision_table[
            "annualized_return"
        ].idxmax(),

        "sharpe_ratio": decision_table[
            "sharpe_ratio"
        ].idxmax(),

        "sortino_ratio": decision_table[
            "sortino_ratio"
        ].idxmax(),

        "maximum_drawdown": decision_table[
            "maximum_drawdown"
        ].idxmax(),

        "calmar_ratio": decision_table[
            "calmar_ratio"
        ].idxmax(),

        "average_turnover": decision_table[
            "average_turnover"
        ].idxmin(),
    },
    name="leader",
)

leaders
# Out:
# total_return              sample
# annualized_return         sample
# sharpe_ratio              sample
# sortino_ratio             sample
# maximum_drawdown     ledoit_wolf
# calmar_ratio              sample
# average_turnover       shrinkage
# Name: leader, dtype: str

# %% [markdown]
# ## 6A.7 — Multi-Objective Research Decision
#
# The baseline comparison does not identify a single covariance
# methodology that dominates every evaluation criterion.
#
# Instead, the results reveal three distinct leadership profiles:
#
# - **Sample covariance** leads on return and risk-adjusted performance.
# - **Ledoit-Wolf covariance** leads on maximum-drawdown protection.
# - **Explicit shrinkage** leads on portfolio turnover.
#
# This indicates that covariance-method selection is inherently
# multi-objective.
#
# The appropriate methodology therefore depends on the relative
# importance assigned to performance, downside protection, and
# implementation stability.

# %%
objective_framework = pd.DataFrame(
    {
        "objective": [
            "Return",
            "Risk-adjusted performance",
            "Downside protection",
            "Implementation stability",
        ],
        "metric": [
            "total_return",
            "sharpe_ratio",
            "maximum_drawdown",
            "average_turnover",
        ],
        "preferred_method": [
            "sample",
            "sample",
            "ledoit_wolf",
            "shrinkage",
        ],
    }
)

objective_framework
# Out:
#                    objective            metric preferred_method
# 0                     Return      total_return           sample
# 1  Risk-adjusted performance      sharpe_ratio           sample
# 2        Downside protection  maximum_drawdown      ledoit_wolf
# 3   Implementation stability  average_turnover        shrinkage

# %%
sample = decision_table.loc["sample"]
shrinkage = decision_table.loc["shrinkage"]
ledoit_wolf = decision_table.loc["ledoit_wolf"]

performance_comparison = pd.DataFrame(
    {
        "sample_vs_shrinkage": {
            "total_return": (
                sample["total_return"]
                - shrinkage["total_return"]
            ),
            "sharpe_ratio": (
                sample["sharpe_ratio"]
                - shrinkage["sharpe_ratio"]
            ),
            "maximum_drawdown": (
                sample["maximum_drawdown"]
                - shrinkage["maximum_drawdown"]
            ),
            "turnover": (
                sample["average_turnover"]
                - shrinkage["average_turnover"]
            ),
        },
        "sample_vs_ledoit_wolf": {
            "total_return": (
                sample["total_return"]
                - ledoit_wolf["total_return"]
            ),
            "sharpe_ratio": (
                sample["sharpe_ratio"]
                - ledoit_wolf["sharpe_ratio"]
            ),
            "maximum_drawdown": (
                sample["maximum_drawdown"]
                - ledoit_wolf["maximum_drawdown"]
            ),
            "turnover": (
                sample["average_turnover"]
                - ledoit_wolf["average_turnover"]
            ),
        },
    }
)

performance_comparison
# Out:
#                   sample_vs_shrinkage  sample_vs_ledoit_wolf
# total_return                 0.088021               0.300910
# sharpe_ratio                 0.021437               0.078208
# maximum_drawdown            -0.014571              -0.056128
# turnover                     0.108755              -0.132900

# %%
# Decision Score
# we'll demonstrate how the decision changes depending on the objective.
# We'll do this by creating a normalized score

score_data = decision_table[
    [
        "total_return",
        "sharpe_ratio",
        "maximum_drawdown",
        "average_turnover",
    ]
].copy()

score_data
# Out:
#              total_return  sharpe_ratio  maximum_drawdown  average_turnover
# method
# sample           0.869704      0.542223         -0.781959          1.219442
# shrinkage        0.781683      0.520786         -0.767388          1.110687
# ledoit_wolf      0.568794      0.464014         -0.725831          1.352342

# %%
#Then normalize the metrics.
# For return, Sharpe and drawdown:

benefit_metrics = [
    "total_return",
    "sharpe_ratio",
    "maximum_drawdown",
]

cost_metrics = [
    "average_turnover",
]

scores = pd.DataFrame(
    index=score_data.index
)

for metric in benefit_metrics:
    minimum = score_data[metric].min()
    maximum = score_data[metric].max()

    scores[metric] = (
        score_data[metric] - minimum
    ) / (
        maximum - minimum
    )

for metric in cost_metrics:
    minimum = score_data[metric].min()
    maximum = score_data[metric].max()

    scores[metric] = (
        maximum - score_data[metric]
    ) / (
        maximum - minimum
    )

scores
# Out:
#              total_return  sharpe_ratio  maximum_drawdown  average_turnover
# method
# sample           1.000000      1.000000          0.000000          0.549958
# shrinkage        0.707486      0.725904          0.259606          1.000000
# ledoit_wolf      0.000000      0.000000          1.000000          0.000000

# %% [markdown]
# ### Weighting Principle
#
# A composite score requires assumptions about the relative importance
# of return, risk-adjusted performance, downside protection, and
# turnover.
#
# Those weights are investment-policy assumptions rather than purely
# empirical facts.
#
# Therefore, CARL does not select arbitrary weights and present the
# resulting score as an objective truth.
#
# Instead, the framework evaluates alternative objective priorities.

# %%
# Scenario-Based Decision Analysis. We'll define three reasonable investor objectives.

decision_scenarios = {
    "performance_focused": {
        "total_return": 0.30,
        "sharpe_ratio": 0.40,
        "maximum_drawdown": 0.20,
        "average_turnover": 0.10,
    },
    "risk_control_focused": {
        "total_return": 0.15,
        "sharpe_ratio": 0.25,
        "maximum_drawdown": 0.50,
        "average_turnover": 0.10,
    },
    "implementation_focused": {
        "total_return": 0.15,
        "sharpe_ratio": 0.20,
        "maximum_drawdown": 0.15,
        "average_turnover": 0.50,
    },
}

# %%
scenario_scores = {}

for scenario, weights in decision_scenarios.items():

    scenario_scores[scenario] = (
        scores[list(weights)]
        .mul(
            pd.Series(weights)
        )
        .sum(axis=1)
    )

scenario_scores = pd.DataFrame(
    scenario_scores
)

scenario_scores
# Out:
#              performance_focused  risk_control_focused  implementation_focused
# method
# sample                  0.754996              0.454996                0.624979
# shrinkage               0.654528              0.517402                0.790245
# ledoit_wolf             0.200000              0.500000                0.150000

# %%
scenario_winners = scenario_scores.idxmax()

scenario_winners
# Out:
# performance_focused          sample
# risk_control_focused      shrinkage
# implementation_focused    shrinkage
# dtype: str

# %% [markdown]
# ## Scenario-Based Interpretation
#
# The scenario analysis demonstrates an important property of the
# research:
#
# > The preferred covariance methodology depends on the objective
# > function.
#
# A performance-focused investor places greater emphasis on return and
# risk-adjusted performance.
#
# A risk-control-focused investor assigns greater importance to
# drawdown protection.
#
# An implementation-focused investor assigns greater importance to
# turnover.
#
# This prevents CARL from reducing a multi-dimensional portfolio
# decision to a single historical performance ranking.

# %% [markdown]
# # Research Decision
#
# ## Baseline recommendation
#
# For the current CARL research specification, **sample covariance is
# the preferred baseline estimator**.
#
# The evidence supporting this choice is:
#
# 1. highest total return;
# 2. highest annualized return;
# 3. highest Sharpe ratio;
# 4. highest Sortino ratio;
# 5. highest Calmar ratio; and
# 6. first-place Sharpe ranking across all tested training windows.
#
# However, this recommendation is conditional.
#
# ### Alternative objectives
#
# **Ledoit-Wolf** is preferable when downside protection receives
# greater importance because it produced the least severe maximum
# drawdown in the baseline comparison.
#
# **Explicit shrinkage** is preferable when implementation stability
# receives greater importance because it produced the lowest turnover.
#
# ### Final research position
#
# The evidence therefore supports sample covariance as the **baseline
# performance-oriented specification**, while retaining shrinkage and
# Ledoit-Wolf as economically meaningful alternatives.
#
# No methodology is declared universally superior.

# %% [markdown]
# ## Scenario-Based Research Conclusion
#
# The scenario analysis demonstrates that covariance-method selection is
# objective-dependent.
#
# Sample covariance achieves the highest composite score under the
# performance-focused objective (0.7550), consistent with its leadership
# in total return, annualized return, Sharpe ratio, Sortino ratio, and
# Calmar ratio.
#
# Shrinkage achieves the highest score under both the risk-control-focused
# objective (0.5174) and the implementation-focused objective (0.7902).
# Its advantage is associated with its lower portfolio turnover and
# competitive downside characteristics.
#
# Ledoit-Wolf does not achieve the highest composite score in any of the
# three scenarios, although it provides the strongest standalone
# maximum-drawdown result in the baseline comparison.
#
# The results therefore do not support a universal covariance winner.
# Instead, they support an objective-dependent methodology choice:
#
# - Sample covariance for performance-oriented research.
# - Shrinkage for a stronger balance between risk control and
#   implementation stability.
# - Ledoit-Wolf remains a relevant robustness benchmark because of its
#   distinct covariance-estimation methodology and downside behavior.
#
# The composite scores are not universal truths. They depend on the
# explicit objective weights selected for each scenario. They are
# therefore used as decision-analysis tools rather than as evidence that
# one estimator is universally superior.

# %% [markdown]
# ### Scenario-Based Decision
#
# The scenario analysis shows that covariance-method selection is
# objective-dependent.
#
# - **Performance-focused:** Sample covariance is preferred.
# - **Risk-control-focused:** Shrinkage is preferred.
# - **Implementation-focused:** Shrinkage is preferred.
#
# Therefore, CARL does not identify a universally superior covariance
# estimator. Instead, it demonstrates that the appropriate methodology
# depends on the research objective and the relative importance assigned
# to performance, risk control, and implementation considerations.
#
# This provides a more decision-oriented conclusion than selecting a
# single estimator solely on the basis of total return.
